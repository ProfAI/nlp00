# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAI/nlp00/blob/master/08%20-%20Deep%20Learning%20e%20Chatbot/chatbot_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning Powered Chatbot con Keras
# In questo notebook creeremo un chatbot rudimentale in Python. Ho definito le conversazioni che il chatbot sarà in grado di gestire all'interno di un file JSON che puoi trovare sulla [repository github del corso](https://github.com/ProfAI/nlp00/blob/master/8%20-%20Chatbot/data/model.json).

# %% [markdown]
# ### Carichiamo il corpus di testo
# Utilizza pure il codice qui sotto per caricare il file JSON

# %%
import urllib.request, json 

with urllib.request.urlopen("https://raw.githubusercontent.com/ProfAI/nlp00/master/08%20-%20Deep%20Learning%20e%20Chatbot/data/model.json") as url:
    data = url.read().decode()
    
corpus = json.loads(data)
corpus
# Out:
# {'intents': [{'name': 'HelloIntent',
#    'responses': ["Ciao, sono MiaoBot, l'assistente virtuale di Miao Mobile, come posso aiutarti ?",
#     "Buongiorno, questa è l'assistenza clienti di Miao Mobile, come posso esserti utile ?"],
#    'samples': ['Ciao', 'Salve', 'hei', 'Ci sei ?', 'Buongiorno', 'Buonasera']},
#   {'name': 'GoodbyeIntent',
#    'responses': ['Grazie per averci contattato ! Buona giornata',
#     'Per qualsiasi cosa ci trovi sempre qui, buona giornata !',
#     'Buona giornata !'],
#    'samples': ['Addio',
#     'Arrivederci',
#     'Buona giornata',
#     'A presto',
#     'Ci vediamo']},
#   {'name': 'ThanksIntent',
#    'responses': ["E' stato un piacere, se hai bisogno di altro non esitare a chiedere",
#     "E' stato un piacere aiutarti",
#     'Figurati, è il mio lavoro :)'],
#    'samples': ['Grazie', 'Ti ringrazio', 'Fantastico']},
#   {'name': 'WhoIntent',
#    'responses': ["Io sono MiaoBot, l'assistente virtuale di Miao Mobile, sono qui 24 ore su 24 per assisterti",
#     "Mi chiamo MiaoBot, sono un'intelligenza artificiale sviluppata da Miao Mobile per assistere ogni cliente"],
#    'samples': ['Chi sei tu ?', 'Come ti chiami ?', 'Con chi sto parlando ?']},
#   {'name': 'CreditIntent',
#    'responses': ["Per conoscere il tuo credito ti basta inviare un messagio al 199 con il testo 'credito'",
#     "Purtroppo io non posso sapere il tuo credito, per conoscerlo ti inviare un SMS con scritto 'credito' al numero 199"],
#    'samples': ['Posso sapere il mio credito ?',
#     'Qual è il mio credito ?',
#     'Quanti soldi ho ?']},
#   {'name': 'PromoListIntent',
#    'responses': ['Ecco le nostre offerte attuali: 1)Miao 4 Hooman: 10 giga e 1000 minuti al mese a 4.99€ 2) Miao Tanti Giga: 100 giga e chiamate illimitate a 12.99€ 3) Miao & Chilli: 30 giga e chiamate illimitate + Netflix incluso a 9.99€ al mese'],
#    'samples': ['Quali sono le vostre offerte ?',
#     'Che offerte avete ?',
#     'Ci sono promozioni ?']},
#   {'name': 'PromoChangeIntent',
#    'responses': ['Certo, puoi scegliere tra una delle seguenti offerte e poi contattare il 199 per eseguire il cambio: 1)Miao 4 Hooman: 10 giga e 1000 minuti al mese a 4.99€ 2) Miao Tanti Giga: 100 giga e chiamate illimitate a 12.99€ 3) Miao & Chilli: 30 giga e chiamate illimitate + Netflix incluso a 9.99€ al mese'],
#    'samples': ['Vorrei cambiare piano tariffario',
#     'Voglio cambiare promozione',
#     "Voglio un'altra promozione"]},
#   {'name': 'ContactIntent',
#    'responses': ['Per parlare con un nostro operatore può contattare il 199',
#     "Il nostro numero verde è 199, subito dopo il messaggi di benvenuto digita 0 per parlare con un'operatore"],
#    'samples': ['Qual è il numero verde ?',
#     "Posso parlare con un'operatore ?"]},
#   {'name': 'FiberIntent',
#    'responses': ['Purtroppo al momento non forniamo servizi per la linea fissa ma ci stiamo attrezzando',
#     'Mi dispiace ma al momento non abbiamo soluzioni per il fisso.'],
#    'samples': ['Avete soluzioni per la fibra ?',
#     'Avete offerte per la linea fissa ?']},
#   {'name': 'GreetingIntent',
#    'responses': ['Mi sento al settimo Cloud ! grazie per avermelo chiesto :)'],
#    'samples': ['Come stai ?', 'Come va ?', 'Come ti senti ?']},
#   {'name': 'WhatIntent',
#    'responses': ['Posso aiutarti a conoscere le ultime offerte di Miao Mobile oppure con qualche problema che stai riscontrando, basta chiedere :)'],
#    'samples': ['Cosa puoi fare ?', 'Come puoi aiutarmi ?']},
#   {'name': 'HelpIntent',
#    'responses': ['Sarò lieto di assisterti ! Come posso aiutarti ?',
#     'Sono qui per aiutarti, dimmi come posso esserti utile :)'],
#    'samples': ['Mi serve aiuto', 'Ho bisogno di assistenza']},
#   {'name': 'BadIntent',
#    'responses': ['Mi dispiace molto di non averti soddisfatto, come posso rimediare ?',
#     'Sono spiacente di sentirtelo dire, posso rimediare in qualche modo ?'],
#    'samples': ['Fai schifo',
#     'Vai a farti friggere',
#     'Sei totalmente inutile']},
#   {'name': 'GenderIntent',
#    'responses': ["Sono un'intelligenza artificiale sviluappata da un team di ricercatori umani e felini nei laboratori di Miao Mobile"],
#    'samples': ['Sei un essere umano ?',
#     'Sei una donna ?',
#     "Sei un'uomo ?",
#     'Sei una donna ?']},
#   {'name': 'AnswerIntent',
#    'responses': ['42'],
#    'samples': ["Qual è la risposta alla domanda fondamentale sulla vita, l'universo e tutto quanto"]},
#   {'name': 'WordEndIntent',
#    'responses': ['Quando i gatti decideranno di conquistarlo',
#     'Quando i gatti impareranno ad aprire le scatolette e non avranno più bisogno degli schiavi umani.'],
#    'samples': ['Quando finirà il mondo ?']}]}

# %% [markdown]
# Il file contiene una serie di **intents** per un chatbot che simula un'operatore dell'assistenza clienti per una fantomatica compagnia telefonica chiamata Miao Mobile. Un'intent corrisponde ad un'azione che il chatbot può eseguire (in questo caso una risposta che può dare), ogni intent contiene questi elementi:
#  - **name**: l'identificativo dell'intent.
#  - **samples**: sono degli esempi di frasi che il chatbot deve imparare a riconoscere.
#  - **responses**: sono le risposte che il chatbot deve fornire per l'intent corrispondente.
#
#
# Questa codifica è basata su quella usata da Amazon Alexa, [qui trovi un'esempio](https://github.com/alexa/skill-sample-python-helloworld-decorators/blob/master/models/en-US.json). Il nostro obiettivo sarà quello di addestare una rete neurale usando le frasi di esempio per predire l'intent corrispondente, per poi usare l'intent per tornare una risposta presa a caso tra quelle disponibili.

# %% [markdown]
# ### Preprocessiamo i dati
# Cominciamo preprocessando i samples per ogni intent, per farlo ci serviremo di spacy, importiamo il modulo e, se non lo abbiamo già fatto, scarichiamo il modulo per la lingua italiana.

# %%
import spacy
# !python -m spacy download it_core_news_sm
# Out:
# Collecting it_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-2.2.5/it_core_news_sm-2.2.5.tar.gz (14.5 MB)
#      |████████████████████████████████| 14.5 MB 8.1 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from it_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (3.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (2.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->it_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->it_core_news_sm==2.2.5) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->it_core_news_sm==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->it_core_news_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->it_core_news_sm==2.2.5) (3.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('it_core_news_sm')

# %% [markdown]
# Iteriamo su ogni sample di ogni intent ed eseguiamo queste trasformazioni sul testo:
#  1. Converiamo tutto in minuscolo.
#  2. Estraiamo i token.
#  3. Verifichiamo che il token non sia un carattere di punteggiatura o una stop word.
#  4. Estraiamo il lemma.
#  5. Aggiungiamo il lemma al documento corrente.
#  6. Se il lemma non è presenta all'interno del dizionario, aggiungiamolo.
#
#
#  Per ogni documento salviamo anche il nome dell'intent corrispondente.

# %%
nlp = spacy.load("it_core_news_sm")

dictionary = set({})
intents = []

docs = []


for intent in corpus["intents"]:
  
  for sample in intent["samples"]:
    
    sample = sample.lower()
    tokens = nlp(sample)
    doc = ""
    
    for token in tokens:
      if(not token.is_punct and not token.is_stop):
        doc+=" "+token.lemma_
        dictionary.add(token.lemma_) # essendo un set, se il lemma è già presente non verrà aggiunto
        
    if(len(doc)>0):
      docs.append(doc.rstrip()) # usiamo rstrip() per rimuovere lo spazio alla fine del documento
      intents.append(intent["name"])
  
print("Lunghezza del dizionario: %d" % len(dictionary))
print(docs)
print(intents)
# Out:
# Lunghezza del dizionario: 57
# [' ciao', ' salvo', ' hei', ' buongiorno', ' buonasera', ' addio', ' arrivederci', ' buono giornata', ' prestare', ' vedere', ' ringraziare', ' fantasticare', ' chiamare', ' parlare', ' potere sapere credito', ' qual essere credito', ' soldo', ' offrire', ' offrire', ' promozione', ' volere cambiare piare tariffario', ' volere cambiare promozione', ' volere una altro promozione', ' qual essere numerare verde', ' potere parlare una operatore', ' soluzione fibra', ' offrire lineare fisso', ' sentire', ' potere', ' potere aiutarmi', ' servire aiutare', ' bisognare assistenza', ' schifare', ' vaio farti friggere', ' totalmente inutile', ' umano', ' donna', ' una', ' donna', ' qual essere rispondere domandare fondamentale lo universo e', ' finire']
# ['HelloIntent', 'HelloIntent', 'HelloIntent', 'HelloIntent', 'HelloIntent', 'GoodbyeIntent', 'GoodbyeIntent', 'GoodbyeIntent', 'GoodbyeIntent', 'GoodbyeIntent', 'ThanksIntent', 'ThanksIntent', 'WhoIntent', 'WhoIntent', 'CreditIntent', 'CreditIntent', 'CreditIntent', 'PromoListIntent', 'PromoListIntent', 'PromoListIntent', 'PromoChangeIntent', 'PromoChangeIntent', 'PromoChangeIntent', 'ContactIntent', 'ContactIntent', 'FiberIntent', 'FiberIntent', 'GreetingIntent', 'WhatIntent', 'WhatIntent', 'HelpIntent', 'HelpIntent', 'BadIntent', 'BadIntent', 'BadIntent', 'GenderIntent', 'GenderIntent', 'GenderIntent', 'GenderIntent', 'AnswerIntent', 'WordEndIntent']

# %% [markdown]
# ### Bag of Words
# Adesso codifichiamo il nostro testo utilizzando una rappresentazione bag of words, come al solito usiamo la classe *CountVectorizer* di sklearn.

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow = CountVectorizer()
X = bow.fit_transform(docs)
X = X.toarray()
X.shape
# Out:
# (41, 56)

# %% [markdown]
# Gli intents sono i target della nostra rete neurale, al momento ogni intent è rappresentato da una stringa (l'identificativo), usiamo la classe *LabelEncoder* per codificarli in numeri.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(intents)
y[:5]
# Out:
# array([8, 8, 8, 8, 8])

# %% [markdown]
# Eseguiamo il one hot encoding per creare le variabili di comodo per il target.
# <br>
# NOTA BENE Usando la classe OneHotEncoder di sklearn avremmo anche potuto evitare di eseguire la codifica dei label prima, dato che questa la effettua in automatico, il motivo per cui lo abbiamo fatto è che l'oggetto LabelEncoder che abbiamo creato ci servirà più avanti quando utilizzeremo la rete che abbiamo addestrato.

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
y = ohe.fit_transform(y.reshape(-1, 1))
y = y.toarray()
y.shape
# Out:
# (41, 16)

# %% [markdown]
# Mescoliamo il dataset usando la funzione shuffle di sklearn.

# %%
from sklearn.utils import shuffle

X, y = shuffle(X, y, random_state=0)

# %% [markdown]
# Adesso siamo pronti per creare la nostra rete neurale artificiale.

# %% [markdown]
# ## Creazione della rete
# Creiamo la nostra archiettura di rete neurale artificiale usando Keras. Inizializziamo un modello sequenziale e aggiungiamo tre strati densi:
# - Uno strato di input con 12 nodi.
# - Uno strato nascosto con 8 nodi.
# - Uno strato di output, con un numero di nodi pari al numero di tags da classificare.

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(12, activation="relu", input_dim=X.shape[1]))
model.add(Dense(8, activation="relu"))
model.add(Dense(y.shape[1], activation="softmax"))

# %% [markdown]
# Compiliamo il modello, usando come come funzione di costo la *categorical crossentropy* e come algoritmo di ottimizzazione *adam*, aggiungiamo anche l'accuracy come metrica.

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# %% [markdown]
# Avviamo l'addestramento con il metodo *.fit()*, impostando come numero di epoche 100.

# %%
model.fit(X, y, epochs=500)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7618 - accuracy: 0.0976
# Epoch 2/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7582 - accuracy: 0.0976
# Epoch 3/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7554 - accuracy: 0.1463
# Epoch 4/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7526 - accuracy: 0.1463
# Epoch 5/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7500 - accuracy: 0.1463
# Epoch 6/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7475 - accuracy: 0.1463
# Epoch 7/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7448 - accuracy: 0.1463
# Epoch 8/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7423 - accuracy: 0.1463
# Epoch 9/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7396 - accuracy: 0.1463
# Epoch 10/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7371 - accuracy: 0.1707
# Epoch 11/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7345 - accuracy: 0.1463
# Epoch 12/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7320 - accuracy: 0.1707
# Epoch 13/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7293 - accuracy: 0.1951
# Epoch 14/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7267 - accuracy: 0.1951
# Epoch 15/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7241 - accuracy: 0.1951
# Epoch 16/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7215 - accuracy: 0.1951
# Epoch 17/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7187 - accuracy: 0.1951
# Epoch 18/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7164 - accuracy: 0.1951
# Epoch 19/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7136 - accuracy: 0.1951
# Epoch 20/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7108 - accuracy: 0.2195
# Epoch 21/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7082 - accuracy: 0.2195
# Epoch 22/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7054 - accuracy: 0.2439
# Epoch 23/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7026 - accuracy: 0.2439
# Epoch 24/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.6999 - accuracy: 0.2439
# Epoch 25/500
# 2/2 [==============================] - 0s 16ms/step - loss: 2.6968 - accuracy: 0.2439
# Epoch 26/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6941 - accuracy: 0.2439
# Epoch 27/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6912 - accuracy: 0.2195
# Epoch 28/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.6883 - accuracy: 0.2195
# Epoch 29/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6853 - accuracy: 0.2195
# Epoch 30/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6824 - accuracy: 0.2195
# Epoch 31/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.6792 - accuracy: 0.2195
# Epoch 32/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6761 - accuracy: 0.2195
# Epoch 33/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6729 - accuracy: 0.2195
# Epoch 34/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6697 - accuracy: 0.2439
# Epoch 35/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6665 - accuracy: 0.2439
# Epoch 36/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6627 - accuracy: 0.2439
# Epoch 37/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6590 - accuracy: 0.2439
# Epoch 38/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6554 - accuracy: 0.2927
# Epoch 39/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6516 - accuracy: 0.2927
# Epoch 40/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6477 - accuracy: 0.2927
# Epoch 41/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6438 - accuracy: 0.2927
# Epoch 42/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6398 - accuracy: 0.3171
# Epoch 43/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6359 - accuracy: 0.2927
# Epoch 44/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6319 - accuracy: 0.2927
# Epoch 45/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6273 - accuracy: 0.2927
# Epoch 46/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6232 - accuracy: 0.2927
# Epoch 47/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.6185 - accuracy: 0.2927
# Epoch 48/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.6139 - accuracy: 0.2927
# Epoch 49/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.6094 - accuracy: 0.2927
# Epoch 50/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6044 - accuracy: 0.2927
# Epoch 51/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5999 - accuracy: 0.2927
# Epoch 52/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5950 - accuracy: 0.2927
# Epoch 53/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5901 - accuracy: 0.2927
# Epoch 54/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5853 - accuracy: 0.2927
# Epoch 55/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5800 - accuracy: 0.2439
# Epoch 56/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5755 - accuracy: 0.2439
# Epoch 57/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5700 - accuracy: 0.2439
# Epoch 58/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5648 - accuracy: 0.2439
# Epoch 59/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5594 - accuracy: 0.2439
# Epoch 60/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5543 - accuracy: 0.2439
# Epoch 61/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5488 - accuracy: 0.2683
# Epoch 62/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.5434 - accuracy: 0.2683
# Epoch 63/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.5377 - accuracy: 0.2683
# Epoch 64/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.5319 - accuracy: 0.2683
# Epoch 65/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5264 - accuracy: 0.2683
# Epoch 66/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5202 - accuracy: 0.2683
# Epoch 67/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5141 - accuracy: 0.2683
# Epoch 68/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5080 - accuracy: 0.2683
# Epoch 69/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5022 - accuracy: 0.2683
# Epoch 70/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4959 - accuracy: 0.2683
# Epoch 71/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4901 - accuracy: 0.2683
# Epoch 72/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.4836 - accuracy: 0.2683
# Epoch 73/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4774 - accuracy: 0.2683
# Epoch 74/500
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4711 - accuracy: 0.2683
# Epoch 75/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4645 - accuracy: 0.2683
# Epoch 76/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4583 - accuracy: 0.2683
# Epoch 77/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.4515 - accuracy: 0.2683
# Epoch 78/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4455 - accuracy: 0.2683
# Epoch 79/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.4390 - accuracy: 0.2683
# Epoch 80/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4324 - accuracy: 0.2683
# Epoch 81/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.4252 - accuracy: 0.2683
# Epoch 82/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.4186 - accuracy: 0.2683
# Epoch 83/500
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4112 - accuracy: 0.2927
# Epoch 84/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.4036 - accuracy: 0.3171
# Epoch 85/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3957 - accuracy: 0.3171
# Epoch 86/500
# 2/2 [==============================] - 0s 11ms/step - loss: 2.3875 - accuracy: 0.2927
# Epoch 87/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3795 - accuracy: 0.3171
# Epoch 88/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3706 - accuracy: 0.3171
# Epoch 89/500
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3633 - accuracy: 0.3171
# Epoch 90/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3544 - accuracy: 0.3171
# Epoch 91/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3461 - accuracy: 0.3171
# Epoch 92/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3375 - accuracy: 0.3171
# Epoch 93/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3295 - accuracy: 0.3171
# Epoch 94/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3210 - accuracy: 0.2927
# Epoch 95/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3127 - accuracy: 0.2927
# Epoch 96/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3045 - accuracy: 0.2927
# Epoch 97/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2959 - accuracy: 0.2927
# Epoch 98/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2875 - accuracy: 0.2927
# Epoch 99/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2790 - accuracy: 0.2927
# Epoch 100/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2705 - accuracy: 0.2927
# Epoch 101/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2618 - accuracy: 0.2927
# Epoch 102/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2531 - accuracy: 0.2927
# Epoch 103/500
# 2/2 [==============================] - 0s 15ms/step - loss: 2.2444 - accuracy: 0.2927
# Epoch 104/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.2356 - accuracy: 0.2927
# Epoch 105/500
# 2/2 [==============================] - 0s 18ms/step - loss: 2.2274 - accuracy: 0.2927
# Epoch 106/500
# 2/2 [==============================] - 0s 19ms/step - loss: 2.2188 - accuracy: 0.2927
# Epoch 107/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2099 - accuracy: 0.2927
# Epoch 108/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2013 - accuracy: 0.2927
# Epoch 109/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1922 - accuracy: 0.3171
# Epoch 110/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1844 - accuracy: 0.3171
# Epoch 111/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1753 - accuracy: 0.3171
# Epoch 112/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1660 - accuracy: 0.3171
# Epoch 113/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1576 - accuracy: 0.3171
# Epoch 114/500
# 2/2 [==============================] - 0s 8ms/step - loss: 2.1487 - accuracy: 0.3659
# Epoch 115/500
# 2/2 [==============================] - 0s 10ms/step - loss: 2.1401 - accuracy: 0.3659
# Epoch 116/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1312 - accuracy: 0.3659
# Epoch 117/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1224 - accuracy: 0.3659
# Epoch 118/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1140 - accuracy: 0.3659
# Epoch 119/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1049 - accuracy: 0.3659
# Epoch 120/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0956 - accuracy: 0.3659
# Epoch 121/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0866 - accuracy: 0.3902
# Epoch 122/500
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0775 - accuracy: 0.3902
# Epoch 123/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0681 - accuracy: 0.3902
# Epoch 124/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0590 - accuracy: 0.3902
# Epoch 125/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0491 - accuracy: 0.3902
# Epoch 126/500
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0399 - accuracy: 0.4146
# Epoch 127/500
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0306 - accuracy: 0.4146
# Epoch 128/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0209 - accuracy: 0.4146
# Epoch 129/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0112 - accuracy: 0.4146
# Epoch 130/500
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0018 - accuracy: 0.4146
# Epoch 131/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9920 - accuracy: 0.4146
# Epoch 132/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9824 - accuracy: 0.4146
# Epoch 133/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9729 - accuracy: 0.4146
# Epoch 134/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9632 - accuracy: 0.4146
# Epoch 135/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9532 - accuracy: 0.4146
# Epoch 136/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9432 - accuracy: 0.4146
# Epoch 137/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9337 - accuracy: 0.4146
# Epoch 138/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9237 - accuracy: 0.4146
# Epoch 139/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9132 - accuracy: 0.4146
# Epoch 140/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9038 - accuracy: 0.4146
# Epoch 141/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8936 - accuracy: 0.4146
# Epoch 142/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8834 - accuracy: 0.4146
# Epoch 143/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8737 - accuracy: 0.4146
# Epoch 144/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8637 - accuracy: 0.4146
# Epoch 145/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8538 - accuracy: 0.4146
# Epoch 146/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.8437 - accuracy: 0.4146
# Epoch 147/500
# 2/2 [==============================] - 0s 11ms/step - loss: 1.8338 - accuracy: 0.4146
# Epoch 148/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8237 - accuracy: 0.4146
# Epoch 149/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8137 - accuracy: 0.4146
# Epoch 150/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8032 - accuracy: 0.4634
# Epoch 151/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.7933 - accuracy: 0.4634
# Epoch 152/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.7836 - accuracy: 0.4634
# Epoch 153/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7736 - accuracy: 0.4634
# Epoch 154/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7637 - accuracy: 0.4634
# Epoch 155/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7537 - accuracy: 0.4634
# Epoch 156/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7438 - accuracy: 0.4878
# Epoch 157/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7338 - accuracy: 0.4878
# Epoch 158/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7239 - accuracy: 0.4878
# Epoch 159/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7139 - accuracy: 0.4878
# Epoch 160/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7035 - accuracy: 0.4878
# Epoch 161/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6936 - accuracy: 0.4878
# Epoch 162/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6833 - accuracy: 0.4878
# Epoch 163/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6742 - accuracy: 0.4878
# Epoch 164/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6642 - accuracy: 0.4878
# Epoch 165/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6539 - accuracy: 0.4878
# Epoch 166/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6439 - accuracy: 0.4878
# Epoch 167/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6340 - accuracy: 0.4878
# Epoch 168/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6243 - accuracy: 0.4878
# Epoch 169/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.6141 - accuracy: 0.5122
# Epoch 170/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6046 - accuracy: 0.5122
# Epoch 171/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5946 - accuracy: 0.5122
# Epoch 172/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5846 - accuracy: 0.5366
# Epoch 173/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.5753 - accuracy: 0.5366
# Epoch 174/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5654 - accuracy: 0.5366
# Epoch 175/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5560 - accuracy: 0.5366
# Epoch 176/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5467 - accuracy: 0.5366
# Epoch 177/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5369 - accuracy: 0.5366
# Epoch 178/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5273 - accuracy: 0.5366
# Epoch 179/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5182 - accuracy: 0.5366
# Epoch 180/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5087 - accuracy: 0.5366
# Epoch 181/500
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4991 - accuracy: 0.5610
# Epoch 182/500
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4895 - accuracy: 0.5854
# Epoch 183/500
# 2/2 [==============================] - 0s 16ms/step - loss: 1.4804 - accuracy: 0.5854
# Epoch 184/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4712 - accuracy: 0.5854
# Epoch 185/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4623 - accuracy: 0.6341
# Epoch 186/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4526 - accuracy: 0.6341
# Epoch 187/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4431 - accuracy: 0.6341
# Epoch 188/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4338 - accuracy: 0.6341
# Epoch 189/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4249 - accuracy: 0.6585
# Epoch 190/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4158 - accuracy: 0.6585
# Epoch 191/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4068 - accuracy: 0.6585
# Epoch 192/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3975 - accuracy: 0.6585
# Epoch 193/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3890 - accuracy: 0.6585
# Epoch 194/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3802 - accuracy: 0.6585
# Epoch 195/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3712 - accuracy: 0.6829
# Epoch 196/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3623 - accuracy: 0.6829
# Epoch 197/500
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3533 - accuracy: 0.6829
# Epoch 198/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3445 - accuracy: 0.6829
# Epoch 199/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3360 - accuracy: 0.6829
# Epoch 200/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3271 - accuracy: 0.6829
# Epoch 201/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3179 - accuracy: 0.6829
# Epoch 202/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3094 - accuracy: 0.6829
# Epoch 203/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3009 - accuracy: 0.6829
# Epoch 204/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2923 - accuracy: 0.6829
# Epoch 205/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2835 - accuracy: 0.6829
# Epoch 206/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2750 - accuracy: 0.6829
# Epoch 207/500
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2662 - accuracy: 0.6829
# Epoch 208/500
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2573 - accuracy: 0.6829
# Epoch 209/500
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2488 - accuracy: 0.6829
# Epoch 210/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2402 - accuracy: 0.6829
# Epoch 211/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2317 - accuracy: 0.6829
# Epoch 212/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2233 - accuracy: 0.6829
# Epoch 213/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2147 - accuracy: 0.6829
# Epoch 214/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2064 - accuracy: 0.6829
# Epoch 215/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1978 - accuracy: 0.6829
# Epoch 216/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1893 - accuracy: 0.6829
# Epoch 217/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1808 - accuracy: 0.6829
# Epoch 218/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1724 - accuracy: 0.6829
# Epoch 219/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1641 - accuracy: 0.6829
# Epoch 220/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1556 - accuracy: 0.6829
# Epoch 221/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1470 - accuracy: 0.7073
# Epoch 222/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1388 - accuracy: 0.7073
# Epoch 223/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1301 - accuracy: 0.7317
# Epoch 224/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1217 - accuracy: 0.7561
# Epoch 225/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1136 - accuracy: 0.7561
# Epoch 226/500
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1047 - accuracy: 0.7561
# Epoch 227/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0957 - accuracy: 0.7561
# Epoch 228/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0873 - accuracy: 0.7561
# Epoch 229/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0779 - accuracy: 0.7561
# Epoch 230/500
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0685 - accuracy: 0.7561
# Epoch 231/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0600 - accuracy: 0.7561
# Epoch 232/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0511 - accuracy: 0.7805
# Epoch 233/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0422 - accuracy: 0.7805
# Epoch 234/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0336 - accuracy: 0.7805
# Epoch 235/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0253 - accuracy: 0.7805
# Epoch 236/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0167 - accuracy: 0.7805
# Epoch 237/500
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0080 - accuracy: 0.7805
# Epoch 238/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9994 - accuracy: 0.7805
# Epoch 239/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9910 - accuracy: 0.7805
# Epoch 240/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9834 - accuracy: 0.7805
# Epoch 241/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9748 - accuracy: 0.7805
# Epoch 242/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9664 - accuracy: 0.7805
# Epoch 243/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9585 - accuracy: 0.7805
# Epoch 244/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9505 - accuracy: 0.8049
# Epoch 245/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9430 - accuracy: 0.8049
# Epoch 246/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9349 - accuracy: 0.8049
# Epoch 247/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9273 - accuracy: 0.8049
# Epoch 248/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9195 - accuracy: 0.8049
# Epoch 249/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9120 - accuracy: 0.8049
# Epoch 250/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9043 - accuracy: 0.8049
# Epoch 251/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8966 - accuracy: 0.8049
# Epoch 252/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8890 - accuracy: 0.8293
# Epoch 253/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.8820 - accuracy: 0.8537
# Epoch 254/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8748 - accuracy: 0.8537
# Epoch 255/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8674 - accuracy: 0.8537
# Epoch 256/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8601 - accuracy: 0.8537
# Epoch 257/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8533 - accuracy: 0.8537
# Epoch 258/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8462 - accuracy: 0.8537
# Epoch 259/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8389 - accuracy: 0.8537
# Epoch 260/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8322 - accuracy: 0.8537
# Epoch 261/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8258 - accuracy: 0.8537
# Epoch 262/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8190 - accuracy: 0.8537
# Epoch 263/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8123 - accuracy: 0.8537
# Epoch 264/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8057 - accuracy: 0.8537
# Epoch 265/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7992 - accuracy: 0.8537
# Epoch 266/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7926 - accuracy: 0.8537
# Epoch 267/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7862 - accuracy: 0.8537
# Epoch 268/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7800 - accuracy: 0.8537
# Epoch 269/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7734 - accuracy: 0.8537
# Epoch 270/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7671 - accuracy: 0.8537
# Epoch 271/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7608 - accuracy: 0.8537
# Epoch 272/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7548 - accuracy: 0.8537
# Epoch 273/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7488 - accuracy: 0.8537
# Epoch 274/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7427 - accuracy: 0.8780
# Epoch 275/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7365 - accuracy: 0.8780
# Epoch 276/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7310 - accuracy: 0.8780
# Epoch 277/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7250 - accuracy: 0.8780
# Epoch 278/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7191 - accuracy: 0.8780
# Epoch 279/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7132 - accuracy: 0.8780
# Epoch 280/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7075 - accuracy: 0.8780
# Epoch 281/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7018 - accuracy: 0.8780
# Epoch 282/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6962 - accuracy: 0.8780
# Epoch 283/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.8780
# Epoch 284/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6849 - accuracy: 0.8780
# Epoch 285/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.8780
# Epoch 286/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6740 - accuracy: 0.8780
# Epoch 287/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6688 - accuracy: 0.8780
# Epoch 288/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6634 - accuracy: 0.8780
# Epoch 289/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6584 - accuracy: 0.8780
# Epoch 290/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6532 - accuracy: 0.8780
# Epoch 291/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6482 - accuracy: 0.8780
# Epoch 292/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6432 - accuracy: 0.8780
# Epoch 293/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6383 - accuracy: 0.8780
# Epoch 294/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6335 - accuracy: 0.8780
# Epoch 295/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6284 - accuracy: 0.8780
# Epoch 296/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6233 - accuracy: 0.8780
# Epoch 297/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6184 - accuracy: 0.8780
# Epoch 298/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6134 - accuracy: 0.8780
# Epoch 299/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6085 - accuracy: 0.8780
# Epoch 300/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6035 - accuracy: 0.8780
# Epoch 301/500
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5983 - accuracy: 0.8780
# Epoch 302/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5931 - accuracy: 0.8780
# Epoch 303/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5879 - accuracy: 0.8780
# Epoch 304/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5830 - accuracy: 0.8780
# Epoch 305/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.8780
# Epoch 306/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.8780
# Epoch 307/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5688 - accuracy: 0.8780
# Epoch 308/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5637 - accuracy: 0.8780
# Epoch 309/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5594 - accuracy: 0.8780
# Epoch 310/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5546 - accuracy: 0.8780
# Epoch 311/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.8780
# Epoch 312/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5455 - accuracy: 0.8780
# Epoch 313/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5408 - accuracy: 0.8780
# Epoch 314/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5364 - accuracy: 0.8780
# Epoch 315/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.8780
# Epoch 316/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5277 - accuracy: 0.8780
# Epoch 317/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5234 - accuracy: 0.8780
# Epoch 318/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5193 - accuracy: 0.8780
# Epoch 319/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5152 - accuracy: 0.8780
# Epoch 320/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5112 - accuracy: 0.8780
# Epoch 321/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5072 - accuracy: 0.8780
# Epoch 322/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5034 - accuracy: 0.8780
# Epoch 323/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4995 - accuracy: 0.8780
# Epoch 324/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4957 - accuracy: 0.8780
# Epoch 325/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4919 - accuracy: 0.8780
# Epoch 326/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4883 - accuracy: 0.8780
# Epoch 327/500
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4846 - accuracy: 0.9024
# Epoch 328/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4805 - accuracy: 0.9024
# Epoch 329/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4770 - accuracy: 0.9024
# Epoch 330/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4734 - accuracy: 0.9024
# Epoch 331/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4696 - accuracy: 0.9024
# Epoch 332/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4662 - accuracy: 0.9024
# Epoch 333/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.9024
# Epoch 334/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4589 - accuracy: 0.9024
# Epoch 335/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4554 - accuracy: 0.9024
# Epoch 336/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4517 - accuracy: 0.9024
# Epoch 337/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4480 - accuracy: 0.9024
# Epoch 338/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4447 - accuracy: 0.9024
# Epoch 339/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4412 - accuracy: 0.9024
# Epoch 340/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4378 - accuracy: 0.9024
# Epoch 341/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4340 - accuracy: 0.9024
# Epoch 342/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.9024
# Epoch 343/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4271 - accuracy: 0.9024
# Epoch 344/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4238 - accuracy: 0.9024
# Epoch 345/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4204 - accuracy: 0.9024
# Epoch 346/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4172 - accuracy: 0.9024
# Epoch 347/500
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4137 - accuracy: 0.9024
# Epoch 348/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.9268
# Epoch 349/500
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4073 - accuracy: 0.9268
# Epoch 350/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4040 - accuracy: 0.9268
# Epoch 351/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4008 - accuracy: 0.9268
# Epoch 352/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3978 - accuracy: 0.9268
# Epoch 353/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3946 - accuracy: 0.9268
# Epoch 354/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3918 - accuracy: 0.9268
# Epoch 355/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3888 - accuracy: 0.9268
# Epoch 356/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3858 - accuracy: 0.9268
# Epoch 357/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3827 - accuracy: 0.9268
# Epoch 358/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3799 - accuracy: 0.9268
# Epoch 359/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3767 - accuracy: 0.9268
# Epoch 360/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3738 - accuracy: 0.9268
# Epoch 361/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3705 - accuracy: 0.9268
# Epoch 362/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3675 - accuracy: 0.9268
# Epoch 363/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.9268
# Epoch 364/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3619 - accuracy: 0.9268
# Epoch 365/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3591 - accuracy: 0.9268
# Epoch 366/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.9268
# Epoch 367/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3534 - accuracy: 0.9268
# Epoch 368/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3506 - accuracy: 0.9268
# Epoch 369/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3478 - accuracy: 0.9512
# Epoch 370/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3450 - accuracy: 0.9512
# Epoch 371/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3425 - accuracy: 0.9512
# Epoch 372/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3397 - accuracy: 0.9512
# Epoch 373/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3372 - accuracy: 0.9512
# Epoch 374/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3346 - accuracy: 0.9512
# Epoch 375/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3321 - accuracy: 0.9512
# Epoch 376/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3298 - accuracy: 0.9512
# Epoch 377/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3274 - accuracy: 0.9512
# Epoch 378/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3250 - accuracy: 0.9512
# Epoch 379/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3226 - accuracy: 0.9512
# Epoch 380/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.9512
# Epoch 381/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3180 - accuracy: 0.9512
# Epoch 382/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3154 - accuracy: 0.9512
# Epoch 383/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.9512
# Epoch 384/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3106 - accuracy: 0.9512
# Epoch 385/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.9512
# Epoch 386/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.9512
# Epoch 387/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3036 - accuracy: 0.9512
# Epoch 388/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3013 - accuracy: 0.9512
# Epoch 389/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2990 - accuracy: 0.9512
# Epoch 390/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2968 - accuracy: 0.9512
# Epoch 391/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2945 - accuracy: 0.9512
# Epoch 392/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2924 - accuracy: 0.9512
# Epoch 393/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2902 - accuracy: 0.9512
# Epoch 394/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2878 - accuracy: 0.9512
# Epoch 395/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.9512
# Epoch 396/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2835 - accuracy: 0.9512
# Epoch 397/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2812 - accuracy: 0.9512
# Epoch 398/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2790 - accuracy: 0.9512
# Epoch 399/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2768 - accuracy: 0.9512
# Epoch 400/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2746 - accuracy: 0.9512
# Epoch 401/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.9512
# Epoch 402/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2702 - accuracy: 0.9512
# Epoch 403/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2683 - accuracy: 0.9756
# Epoch 404/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2664 - accuracy: 0.9756
# Epoch 405/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2642 - accuracy: 0.9756
# Epoch 406/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2622 - accuracy: 0.9756
# Epoch 407/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9756
# Epoch 408/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2583 - accuracy: 0.9756
# Epoch 409/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2563 - accuracy: 0.9756
# Epoch 410/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2543 - accuracy: 0.9756
# Epoch 411/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2524 - accuracy: 0.9756
# Epoch 412/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2504 - accuracy: 0.9756
# Epoch 413/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2486 - accuracy: 0.9756
# Epoch 414/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2468 - accuracy: 0.9756
# Epoch 415/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2448 - accuracy: 0.9756
# Epoch 416/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2428 - accuracy: 0.9756
# Epoch 417/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2409 - accuracy: 0.9756
# Epoch 418/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2390 - accuracy: 0.9756
# Epoch 419/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2372 - accuracy: 0.9756
# Epoch 420/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2353 - accuracy: 0.9756
# Epoch 421/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2333 - accuracy: 0.9756
# Epoch 422/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2315 - accuracy: 0.9756
# Epoch 423/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.9756
# Epoch 424/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2279 - accuracy: 0.9756
# Epoch 425/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2261 - accuracy: 0.9756
# Epoch 426/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2242 - accuracy: 0.9756
# Epoch 427/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2221 - accuracy: 0.9756
# Epoch 428/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2205 - accuracy: 0.9756
# Epoch 429/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2185 - accuracy: 0.9756
# Epoch 430/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.9756
# Epoch 431/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2148 - accuracy: 0.9756
# Epoch 432/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2128 - accuracy: 0.9756
# Epoch 433/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9756
# Epoch 434/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2087 - accuracy: 0.9756
# Epoch 435/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9756
# Epoch 436/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2049 - accuracy: 0.9756
# Epoch 437/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2031 - accuracy: 0.9756
# Epoch 438/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.9756
# Epoch 439/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.9756
# Epoch 440/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1978 - accuracy: 0.9756
# Epoch 441/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1961 - accuracy: 0.9756
# Epoch 442/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1944 - accuracy: 0.9756
# Epoch 443/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1928 - accuracy: 0.9756
# Epoch 444/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1912 - accuracy: 0.9756
# Epoch 445/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1896 - accuracy: 0.9756
# Epoch 446/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.9756
# Epoch 447/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1863 - accuracy: 0.9756
# Epoch 448/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1848 - accuracy: 0.9756
# Epoch 449/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1832 - accuracy: 0.9756
# Epoch 450/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1815 - accuracy: 0.9756
# Epoch 451/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1801 - accuracy: 0.9756
# Epoch 452/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1785 - accuracy: 0.9756
# Epoch 453/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1770 - accuracy: 0.9756
# Epoch 454/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1754 - accuracy: 0.9756
# Epoch 455/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1736 - accuracy: 0.9756
# Epoch 456/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1720 - accuracy: 0.9756
# Epoch 457/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9756
# Epoch 458/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9756
# Epoch 459/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1670 - accuracy: 0.9756
# Epoch 460/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9756
# Epoch 461/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9756
# Epoch 462/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9756
# Epoch 463/500
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1605 - accuracy: 0.9756
# Epoch 464/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1590 - accuracy: 0.9756
# Epoch 465/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.9756
# Epoch 466/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.9756
# Epoch 467/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9756
# Epoch 468/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1533 - accuracy: 0.9756
# Epoch 469/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1518 - accuracy: 0.9756
# Epoch 470/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1505 - accuracy: 0.9756
# Epoch 471/500
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1492 - accuracy: 0.9756
# Epoch 472/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1478 - accuracy: 0.9756
# Epoch 473/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 0.9756
# Epoch 474/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9756
# Epoch 475/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1438 - accuracy: 0.9756
# Epoch 476/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1424 - accuracy: 0.9756
# Epoch 477/500
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1412 - accuracy: 0.9756
# Epoch 478/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9756
# Epoch 479/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.9756
# Epoch 480/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1376 - accuracy: 0.9756
# Epoch 481/500
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1364 - accuracy: 0.9756
# Epoch 482/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.9756
# Epoch 483/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1341 - accuracy: 0.9756
# Epoch 484/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1330 - accuracy: 0.9756
# Epoch 485/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9756
# Epoch 486/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1307 - accuracy: 0.9756
# Epoch 487/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9756
# Epoch 488/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.9756
# Epoch 489/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1276 - accuracy: 0.9756
# Epoch 490/500
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1266 - accuracy: 0.9756
# Epoch 491/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1257 - accuracy: 0.9756
# Epoch 492/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9756
# Epoch 493/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9756
# Epoch 494/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9756
# Epoch 495/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9756
# Epoch 496/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9756
# Epoch 497/500
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9756
# Epoch 498/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1187 - accuracy: 0.9756
# Epoch 499/500
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1178 - accuracy: 0.9756
# Epoch 500/500
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1169 - accuracy: 0.9756

# %% [markdown]
# ### Testiamo il chatbot
# Adesso che la nostra rete è in grado di riconsocere l'intent di una richiesta, usiamola per creare il nostro chatbot. Definiamo una prima funzione che prende in ingresso la richiesta dell'utente e la processa esattamente come abbiamo processato i dati dell'addestramento.

# %%
def preprocess(sentence):
  
  tokens = nlp(sentence.lower())
  doc = ""
  
  for token in tokens:
    if(not token.is_punct and not token.is_stop):
      doc+=" "+token.lemma_

  x = bow.transform([doc])
  
  return x

# %% [markdown]
# Definiamo una seconda funzione che prendendo in input un'intent ritorna la rispostsa del chatbot corrispondente a quell'intent. Per un'intent possono essere disponibili più risposte equivalenti, usiamo la funzione *choice* del modulo *random* per selezionare una delle risposte dalla lista a caso.

# %%
from random import choice

def get_response(intent_name):
  
  for intent in corpus["intents"]:
    if(intent["name"]==intent_name):
      return choice(intent["responses"])

# %% [markdown]
# Adesso creiamo il core del chatbot, una funzione che prende in input la richiesta, la preprocessa, predice l'intent e ritorna la risposta.

# %%
def chatbot(sentence):
  
  x = preprocess(sentence)
  y_proba = model.predict(x)[0]
  if(y_proba.max()>.7):
    y = y_proba.argmax()
    intent = le.inverse_transform([y])
    return get_response(intent)
  else:
    return "Temo proprio di non aver capito"

# %% [markdown]
# Ed adesso proviamo a chattare con il nostro chatbot (per chiudere la conversazione scriviamo 'arrivederci')

# %%
sentence = ""

while(sentence.lower()!="arrivederci"):
  sentence = input("Tu: ")
  response = chatbot(sentence)
  print("Chatbot: "+response)
# Out:
# Tu: Arrivederci
# Chatbot: Grazie per averci contattato ! Buona giornata

# %% [markdown]
# ### Input multipli
# L'input inserito dall'utente può anche contenere diverse richieste, usando *spacy* e l'attributo *.sents* possiamo dividerle e processarle singolarmente.

# %%
def preprocess(sentence):
  
  tokens = nlp(sentence)
  docs = []
  
  for sent in tokens.sents:
    
    doc = ""
    
    for token in sent:
      if(not token.is_punct and not token.is_stop):
        doc+=" "+token.lemma_
    
    docs.append(doc)
    
  X = bow.transform(docs)
  
  return X

# %% [markdown]
# Adesso la funzione response dovrà accettare una lista di tags e ritornare un'unica risposta unendo le risposte per ogni tag.

# %%
from random import choice

def get_response(intents_name):
  
  response = ""
  
  for intent_name in intents_name:
  
    for intent in corpus["intents"]:
      if(intent["name"]==intent_name):
        response+=choice(intent["responses"])+" "
    
  return response

# %% [markdown]
# Proviamo di nuovo a chiacchierare con il nostro chatbot.

# %%
sentence = None

while(sentence!="bye" and sentence!=""):
  sentence = input("Tu: ")
  response = chatbot(sentence)
  print("Chatbot: "+response)
# Out:
# Tu: Ciao amico mio ! Come ti senti oggi ?
# Chatbot: Hei, felice di vederti Sto benone grazie !
# Tu: bye
# Chatbot: Ciao amico
